# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.datasets import get_rdataset
from sklearn.preprocessing import StandardScaler
from ISLP import load_data

# %%
from sklearn.cluster import \
     (KMeans,
      AgglomerativeClustering)
from scipy.cluster.hierarchy import \
     (dendrogram,
      cut_tree)
from ISLP.cluster import compute_linkage

# %%
# Load the data

Auto = load_data('Auto')
Auto
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0          86    2790
# vw pickup                  44.0          4          97.0          52    2130
# dodge rampage              32.0          4         135.0          84    2295
# ford ranger                28.0          4         120.0          79    2625
# chevy s-10                 31.0          4         119.0          82    2720
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1
# ...                                 ...   ...     ...
# ford mustang gl                    15.6    82       1
# vw pickup                          24.6    82       2
# dodge rampage                      11.6    82       1
# ford ranger                        18.6    82       1
# chevy s-10                         19.4    82       1
#
# [392 rows x 8 columns]

# %%
# We can also impute the missing values of "horsepower" as we did previously

Auto['horsepower'].replace('?','104',inplace=True)
Auto['horsepower'] = pd.to_numeric(Auto['horsepower'])
Auto.dtypes
# Out:
# /var/folders/7v/vty5zngd6bz1whcwtx15zmp00000gn/T/ipykernel_23846/1340562362.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Auto['horsepower'].replace('?','104',inplace=True)
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# dtype: object

# %%
# We won't use "name" in clustering--there are way too many levels to be useful. 
# Instead, we'll make the name of each car the index, so that we can use it in dendrograms.

Auto.index = Auto['name']
Auto.drop(columns='name', axis=1, inplace=True)
Auto
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/envs/islp/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 4
#       1 # We won't use "name" in clustering--there are way too many levels to be useful.
#       2 # Instead, we'll make the name of each car the index, so that we can use it in dendrograms.
# ----> 4 Auto.index = Auto['name']
#       5 Auto.drop(columns='name', axis=1, inplace=True)
#       6 Auto
#
# File /opt/miniconda3/envs/islp/lib/python3.13/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File /opt/miniconda3/envs/islp/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'name'

# %%
# Let's use just a sample of 10 vehicles to start
# We'll use this to get a sense of what the clusters seem to look like

import random
random.seed(10) # ALWAYS set the seed! Otherwise we can't replicate our results

# Create a random sample by randomly choosing row indices
index = random.sample(range(Auto.shape[0]), 10)

sample10 = Auto.iloc[index]
sample10
# Out:
#                                     mpg  cylinders  displacement  horsepower  \
# name
# maxda glc deluxe                   34.1          4          86.0          65
# amc hornet                         18.0          6         199.0          97
# chevrolet caprice classic          17.5          8         305.0         145
# oldsmobile cutlass salon brougham  19.9          8         260.0         110
# mercedes benz 300d                 25.4          5         183.0          77
# plymouth fury iii                  14.0          8         440.0         215
# oldsmobile vista cruiser           12.0          8         350.0         180
# dodge colt m/m                     33.5          4          98.0          83
# chevrolet malibu                   20.5          6         200.0          95
# toyota corona                      31.0          4          76.0          52
#
#                                    weight  acceleration  year  origin
# name
# maxda glc deluxe                     1975          15.2    79       3
# amc hornet                           2774          15.5    70       1
# chevrolet caprice classic            3880          12.5    77       1
# oldsmobile cutlass salon brougham    3365          15.5    78       1
# mercedes benz 300d                   3530          20.1    79       2
# plymouth fury iii                    4312           8.5    70       1
# oldsmobile vista cruiser             4499          12.5    73       1
# dodge colt m/m                       2075          15.9    77       1
# chevrolet malibu                     3155          18.2    78       1
# toyota corona                        1649          16.5    74       3

# %% [markdown]
# ## Hierarchical Clustering

# %%
# Let's do an initial clustering exercise on the Auto data as is

HClust = AgglomerativeClustering
hc_comp = HClust(distance_threshold=0,
                 n_clusters=None,
                 linkage='complete')
hc_comp.fit(sample10)
# Out:
# AgglomerativeClustering(distance_threshold=0, linkage='complete',
#                         n_clusters=None)

# %%
# We can create a dendrogram using matplotlib

linkage_comp = compute_linkage(hc_comp)
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
dendrogram(linkage_comp,
           ax=ax,
           leaf_rotation=90,
           labels=sample10.index,
           color_threshold=-np.inf,
           above_threshold_color='black');

# %%
# We can even add colors based on the selected clusters

fig, ax = plt.subplots(1, 1, figsize=(8, 8))
dendrogram(linkage_comp,
           ax=ax,
           leaf_rotation=90,
           labels=sample10.index,
           color_threshold=1000, # this is the important part 
           above_threshold_color='black');

# %%
# We can cut the tree (by number of clusters or by height) to get an array of cluster assignments

cut_tree(linkage_comp, n_clusters=3).T
#cut_tree(linkage_comp, height=1000)
# Out:
# array([[0, 1, 2, 1, 1, 2, 2, 0, 1, 0]])

# %%
# Let's attach the cluster assignments to our data
# and sort by cluster number

sample10['cluster']=cut_tree(linkage_comp, n_clusters=3)
sample10.sort_values('cluster')
# Out:
# /var/folders/7v/vty5zngd6bz1whcwtx15zmp00000gn/T/ipykernel_23846/1814099651.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample10['cluster']=cut_tree(linkage_comp, n_clusters=3)
#                                     mpg  cylinders  displacement  horsepower  \
# name
# maxda glc deluxe                   34.1          4          86.0          65
# dodge colt m/m                     33.5          4          98.0          83
# toyota corona                      31.0          4          76.0          52
# amc hornet                         18.0          6         199.0          97
# oldsmobile cutlass salon brougham  19.9          8         260.0         110
# mercedes benz 300d                 25.4          5         183.0          77
# chevrolet malibu                   20.5          6         200.0          95
# chevrolet caprice classic          17.5          8         305.0         145
# plymouth fury iii                  14.0          8         440.0         215
# oldsmobile vista cruiser           12.0          8         350.0         180
#
#                                    weight  acceleration  year  origin  cluster
# name
# maxda glc deluxe                     1975          15.2    79       3        0
# dodge colt m/m                       2075          15.9    77       1        0
# toyota corona                        1649          16.5    74       3        0
# amc hornet                           2774          15.5    70       1        1
# oldsmobile cutlass salon brougham    3365          15.5    78       1        1
# mercedes benz 300d                   3530          20.1    79       2        1
# chevrolet malibu                     3155          18.2    78       1        1
# chevrolet caprice classic            3880          12.5    77       1        2
# plymouth fury iii                    4312           8.5    70       1        2
# oldsmobile vista cruiser             4499          12.5    73       1        2

# %%
# Hmm, our clusters seem to be highly influenced by "weight"

sample10.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_98845_row0_col0, #T_98845_row1_col1, #T_98845_row2_col2, #T_98845_row3_col3, #T_98845_row4_col4, #T_98845_row5_col5, #T_98845_row6_col6, #T_98845_row7_col7, #T_98845_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_98845_row0_col1, #T_98845_row0_col2, #T_98845_row0_col4, #T_98845_row0_col8, #T_98845_row1_col7, #T_98845_row3_col5, #T_98845_row3_col6, #T_98845_row5_col3, #T_98845_row8_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_98845_row0_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_98845_row0_col5 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_98845_row0_col6 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_98845_row0_col7 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_98845_row1_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_98845_row1_col2, #T_98845_row2_col1 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_98845_row1_col3 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_98845_row1_col4, #T_98845_row8_col3 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_98845_row1_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_98845_row1_col6, #T_98845_row7_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_98845_row1_col8, #T_98845_row8_col1 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_98845_row2_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_98845_row2_col3, #T_98845_row3_col2 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_98845_row2_col4, #T_98845_row4_col2 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_98845_row2_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_98845_row2_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_98845_row2_col7, #T_98845_row8_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_98845_row2_col8, #T_98845_row8_col2 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_98845_row3_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_98845_row3_col1 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_98845_row3_col4, #T_98845_row4_col3 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_98845_row3_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_98845_row3_col8, #T_98845_row4_col1 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_98845_row4_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_98845_row4_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_98845_row4_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_98845_row4_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_98845_row4_col8, #T_98845_row8_col4 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_98845_row5_col0 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_98845_row5_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_98845_row5_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_98845_row5_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_98845_row5_col6 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_98845_row5_col7 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_98845_row5_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_98845_row6_col0 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_98845_row6_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_98845_row6_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_98845_row6_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_98845_row6_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_98845_row6_col5 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_98845_row6_col7 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_98845_row6_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_98845_row7_col0 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_98845_row7_col1, #T_98845_row7_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_98845_row7_col4, #T_98845_row8_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_98845_row7_col5 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_98845_row7_col6 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_98845_row7_col8 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_98845_row8_col6 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_98845">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98845_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_98845_level0_col1" class="col_heading level0 col1" >cylinders</th>
#       <th id="T_98845_level0_col2" class="col_heading level0 col2" >displacement</th>
#       <th id="T_98845_level0_col3" class="col_heading level0 col3" >horsepower</th>
#       <th id="T_98845_level0_col4" class="col_heading level0 col4" >weight</th>
#       <th id="T_98845_level0_col5" class="col_heading level0 col5" >acceleration</th>
#       <th id="T_98845_level0_col6" class="col_heading level0 col6" >year</th>
#       <th id="T_98845_level0_col7" class="col_heading level0 col7" >origin</th>
#       <th id="T_98845_level0_col8" class="col_heading level0 col8" >cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98845_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_98845_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_98845_row0_col1" class="data row0 col1" >-0.918681</td>
#       <td id="T_98845_row0_col2" class="data row0 col2" >-0.909348</td>
#       <td id="T_98845_row0_col3" class="data row0 col3" >-0.828797</td>
#       <td id="T_98845_row0_col4" class="data row0 col4" >-0.894313</td>
#       <td id="T_98845_row0_col5" class="data row0 col5" >0.530908</td>
#       <td id="T_98845_row0_col6" class="data row0 col6" >0.528792</td>
#       <td id="T_98845_row0_col7" class="data row0 col7" >0.697848</td>
#       <td id="T_98845_row0_col8" class="data row0 col8" >-0.938371</td>
#     </tr>
#     <tr>
#       <th id="T_98845_level0_row1" class="row_heading level0 row1" >cylinders</th>
#       <td id="T_98845_row1_col0" class="data row1 col0" >-0.918681</td>
#       <td id="T_98845_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_98845_row1_col2" class="data row1 col2" >0.922417</td>
#       <td id="T_98845_row1_col3" class="data row1 col3" >0.841400</td>
#       <td id="T_98845_row1_col4" class="data row1 col4" >0.881008</td>
#       <td id="T_98845_row1_col5" class="data row1 col5" >-0.618561</td>
#       <td id="T_98845_row1_col6" class="data row1 col6" >-0.327372</td>
#       <td id="T_98845_row1_col7" class="data row1 col7" >-0.693135</td>
#       <td id="T_98845_row1_col8" class="data row1 col8" >0.911290</td>
#     </tr>
#     <tr>
#       <th id="T_98845_level0_row2" class="row_heading level0 row2" >displacement</th>
#       <td id="T_98845_row2_col0" class="data row2 col0" >-0.909348</td>
#       <td id="T_98845_row2_col1" class="data row2 col1" >0.922417</td>
#       <td id="T_98845_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_98845_row2_col3" class="data row2 col3" >0.964484</td>
#       <td id="T_98845_row2_col4" class="data row2 col4" >0.934470</td>
#       <td id="T_98845_row2_col5" class="data row2 col5" >-0.731221</td>
#       <td id="T_98845_row2_col6" class="data row2 col6" >-0.477063</td>
#       <td id="T_98845_row2_col7" class="data row2 col7" >-0.643690</td>
#       <td id="T_98845_row2_col8" class="data row2 col8" >0.945778</td>
#     </tr>
#     <tr>
#       <th id="T_98845_level0_row3" class="row_heading level0 row3" >horsepower</th>
#       <td id="T_98845_row3_col0" class="data row3 col0" >-0.828797</td>
#       <td id="T_98845_row3_col1" class="data row3 col1" >0.841400</td>
#       <td id="T_98845_row3_col2" class="data row3 col2" >0.964484</td>
#       <td id="T_98845_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_98845_row3_col4" class="data row3 col4" >0.864991</td>
#       <td id="T_98845_row3_col5" class="data row3 col5" >-0.842980</td>
#       <td id="T_98845_row3_col6" class="data row3 col6" >-0.540067</td>
#       <td id="T_98845_row3_col7" class="data row3 col7" >-0.619998</td>

# %%
# Remove the cluster assignment column so we can start over...

sample10.drop(columns='cluster', axis=1, inplace=True)
# Out:
# /var/folders/7v/vty5zngd6bz1whcwtx15zmp00000gn/T/ipykernel_23846/325604847.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample10.drop(columns='cluster', axis=1, inplace=True)

# %%
# Let's standardize the data before clustering

scaler = StandardScaler()
sample10_scale = scaler.fit_transform(sample10)
sample10_scale
# Out:
# array([[ 1.51835735, -1.23529412, -1.17303224, -0.94339466, -1.22095411,
#          0.05202489,  1.05289947,  1.86052102],
#        [-0.60549611, -0.05882353, -0.18161382, -0.29971387, -0.36999255,
#          0.14957155, -1.6545563 , -0.62017367],
#        [-0.67145429,  1.11764706,  0.74838931,  0.66580732,  0.80793422,
#         -0.82589508,  0.45124263, -0.62017367],
#        [-0.35485502,  1.11764706,  0.35357666, -0.03821855,  0.2594421 ,
#          0.14957155,  0.75207105, -0.62017367],
#        [ 0.37068498, -0.64705882, -0.32199165, -0.70201436,  0.43517258,
#          1.64528705,  1.05289947,  0.62017367],
#        [-1.13316157,  1.11764706,  1.93282724,  2.07385905,  1.26802858,
#         -2.12651725, -1.6545563 , -0.62017367],
#        [-1.39699429,  1.11764706,  1.14320195,  1.36983319,  1.4671898 ,
#         -0.82589508, -0.75207105, -0.62017367],
#        [ 1.43920753, -1.23529412, -1.06774887, -0.58132422, -1.11445079,
#          0.27963377,  0.45124263, -0.62017367],
#        [-0.2757052 , -0.05882353, -0.1728402 , -0.33994392,  0.03578512,
#          1.02749152,  0.75207105, -0.62017367],
#        [ 1.10941662, -1.23529412, -1.26076838, -1.20488998, -1.56815495,
#          0.47472709, -0.45124263,  1.86052102]])

# %%
# We'll run the algorithm again
# Can we update this block to add colors for 3 clusters?

hc_comp_scale = HClust(distance_threshold=0,
                       n_clusters=None,
                       linkage='complete').fit(sample10_scale)
linkage_comp_scale = compute_linkage(hc_comp_scale)
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
dendrogram(linkage_comp_scale, ax=ax, 
           leaf_rotation=90, labels=sample10.index,
           color_threshold=-np.inf, above_threshold_color='black')
ax.set_title("Hierarchical Clustering with Scaled Features");

# %%
# Let's compare the clusters from before and after standardizing

sample10['cluster'] = cut_tree(linkage_comp, n_clusters=3)
sample10['cluster_scale'] = cut_tree(linkage_comp_scale, n_clusters=3)
sample10.sort_values('cluster')
# Out:
# /var/folders/7v/vty5zngd6bz1whcwtx15zmp00000gn/T/ipykernel_23846/2624432564.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample10['cluster'] = cut_tree(linkage_comp, n_clusters=3)
# /var/folders/7v/vty5zngd6bz1whcwtx15zmp00000gn/T/ipykernel_23846/2624432564.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample10['cluster_scale'] = cut_tree(linkage_comp_scale, n_clusters=3)
#                                     mpg  cylinders  displacement  horsepower  \
# name
# maxda glc deluxe                   34.1          4          86.0          65
# dodge colt m/m                     33.5          4          98.0          83
# toyota corona                      31.0          4          76.0          52
# amc hornet                         18.0          6         199.0          97
# oldsmobile cutlass salon brougham  19.9          8         260.0         110
# mercedes benz 300d                 25.4          5         183.0          77
# chevrolet malibu                   20.5          6         200.0          95
# chevrolet caprice classic          17.5          8         305.0         145
# plymouth fury iii                  14.0          8         440.0         215
# oldsmobile vista cruiser           12.0          8         350.0         180
#
#                                    weight  acceleration  year  origin  \
# name
# maxda glc deluxe                     1975          15.2    79       3
# dodge colt m/m                       2075          15.9    77       1
# toyota corona                        1649          16.5    74       3
# amc hornet                           2774          15.5    70       1
# oldsmobile cutlass salon brougham    3365          15.5    78       1
# mercedes benz 300d                   3530          20.1    79       2
# chevrolet malibu                     3155          18.2    78       1
# chevrolet caprice classic            3880          12.5    77       1
# plymouth fury iii                    4312           8.5    70       1
# oldsmobile vista cruiser             4499          12.5    73       1
#
#                                    cluster  cluster_scale
# name
# maxda glc deluxe                         0              0
# dodge colt m/m                           0              0
# toyota corona                            0              0
# amc hornet                               1              1
# oldsmobile cutlass salon brougham        1              1
# mercedes benz 300d                       1              1
# chevrolet malibu                         1              1
# chevrolet caprice classic                2              1
# plymouth fury iii                        2              2
# oldsmobile vista cruiser                 2              2

# %%
# Other types of linkage

hc_sing_scale = HClust(distance_threshold=0,
                       n_clusters=None,
                       linkage='single').fit(sample10_scale)
linkage_sing_scale = compute_linkage(hc_sing_scale)

hc_avg_scale = HClust(distance_threshold=0,
                      n_clusters=None,
                      linkage='average').fit(sample10_scale)
linkage_avg_scale = compute_linkage(hc_avg_scale)

# %%
fig, axes = plt.subplots(nrows=1,ncols=3,figsize=(15, 5))

dendrogram(linkage_comp_scale, ax=axes[0], 
           leaf_rotation=90, labels=sample10.index,
           color_threshold=5, above_threshold_color='black')
dendrogram(linkage_sing_scale, ax=axes[1], 
           leaf_rotation=90, labels=sample10.index,
           color_threshold=2.6, above_threshold_color='black')
dendrogram(linkage_avg_scale, ax=axes[2], 
           leaf_rotation=90, labels=sample10.index,
           color_threshold=3.5, above_threshold_color='black')
ax.set_title("Hierarchical Clustering with Scaled Features");

# %%
# We're done with the hierarchical cluster assignment columns, so we'll drop them before moving on

sample10.drop(columns=['cluster','cluster_scale'], axis=1, inplace=True)
# Out:
# /var/folders/7v/vty5zngd6bz1whcwtx15zmp00000gn/T/ipykernel_23846/4109568782.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample10.drop(columns=['cluster','cluster_scale'], axis=1, inplace=True)

# %% [markdown]
# ## $K$-Means Clustering

# %%
# Run a single K-means with K=3

kmeans = KMeans(n_clusters=3,
                random_state=1,
                n_init=1).fit(sample10_scale)

# %%
# Get the cluster assignments 

cluster_km = pd.DataFrame(kmeans.labels_)
cluster_km.index=sample10.index
cluster_km
# Out:
#                                    0
# name
# maxda glc deluxe                   2
# amc hornet                         1
# chevrolet caprice classic          1
# oldsmobile cutlass salon brougham  1
# mercedes benz 300d                 0
# plymouth fury iii                  1
# oldsmobile vista cruiser           1
# dodge colt m/m                     2
# chevrolet malibu                   0
# toyota corona                      2

# %%
# Add the cluster assignments to the data

sample10['cluster_km']=cluster_km
sample10.sort_values('cluster_km')
# Out:
# /var/folders/7v/vty5zngd6bz1whcwtx15zmp00000gn/T/ipykernel_23846/679916727.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample10['cluster_km']=cluster_km
#                                     mpg  cylinders  displacement  horsepower  \
# name
# mercedes benz 300d                 25.4          5         183.0          77
# chevrolet malibu                   20.5          6         200.0          95
# amc hornet                         18.0          6         199.0          97
# chevrolet caprice classic          17.5          8         305.0         145
# oldsmobile cutlass salon brougham  19.9          8         260.0         110
# plymouth fury iii                  14.0          8         440.0         215
# oldsmobile vista cruiser           12.0          8         350.0         180
# maxda glc deluxe                   34.1          4          86.0          65
# dodge colt m/m                     33.5          4          98.0          83
# toyota corona                      31.0          4          76.0          52
#
#                                    weight  acceleration  year  origin  \
# name
# mercedes benz 300d                   3530          20.1    79       2
# chevrolet malibu                     3155          18.2    78       1
# amc hornet                           2774          15.5    70       1
# chevrolet caprice classic            3880          12.5    77       1
# oldsmobile cutlass salon brougham    3365          15.5    78       1
# plymouth fury iii                    4312           8.5    70       1
# oldsmobile vista cruiser             4499          12.5    73       1
# maxda glc deluxe                     1975          15.2    79       3
# dodge colt m/m                       2075          15.9    77       1
# toyota corona                        1649          16.5    74       3
#
#                                    cluster_km
# name
# mercedes benz 300d                          0
# chevrolet malibu                            0
# amc hornet                                  1
# chevrolet caprice classic                   1
# oldsmobile cutlass salon brougham           1
# plymouth fury iii                           1
# oldsmobile vista cruiser                    1
# maxda glc deluxe                            2
# dodge colt m/m                              2
# toyota corona                               2

# %%
# Even though the data is 8-dimensional, we can plot pairs at a time

fig, ax = plt.subplots(1, 1, figsize=(8,8))
ax.scatter(sample10['mpg'], sample10['weight'], c=sample10['cluster_km'])
ax.set_title("K-Means Clustering Results with K=3")
ax.set_xlabel('mpg')
ax.set_ylabel('weight');

# %%
# What happens if we change the initial randomization?

kmeans2 = KMeans(n_clusters=3,
                random_state=2,
                n_init=1).fit(sample10_scale)
cluster_km2 = pd.DataFrame(kmeans2.labels_)
cluster_km2.index=sample10.index
cluster_km2
# Out:
#                                    0
# name
# maxda glc deluxe                   0
# amc hornet                         2
# chevrolet caprice classic          2
# oldsmobile cutlass salon brougham  2
# mercedes benz 300d                 0
# plymouth fury iii                  1
# oldsmobile vista cruiser           2
# dodge colt m/m                     0
# chevrolet malibu                   0
# toyota corona                      0

# %%
# That wasn't helpful at all...let's append that column of cluster assignments to the existing data

sample10['cluster_km2']=cluster_km2
sample10.sort_values('cluster_km2')
# Out:
# /var/folders/7v/vty5zngd6bz1whcwtx15zmp00000gn/T/ipykernel_23846/4252976319.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample10['cluster_km2']=cluster_km2
#                                     mpg  cylinders  displacement  horsepower  \
# name
# maxda glc deluxe                   34.1          4          86.0          65
# mercedes benz 300d                 25.4          5         183.0          77
# dodge colt m/m                     33.5          4          98.0          83
# chevrolet malibu                   20.5          6         200.0          95
# toyota corona                      31.0          4          76.0          52
# plymouth fury iii                  14.0          8         440.0         215
# amc hornet                         18.0          6         199.0          97
# chevrolet caprice classic          17.5          8         305.0         145
# oldsmobile cutlass salon brougham  19.9          8         260.0         110
# oldsmobile vista cruiser           12.0          8         350.0         180
#
#                                    weight  acceleration  year  origin  \
# name
# maxda glc deluxe                     1975          15.2    79       3
# mercedes benz 300d                   3530          20.1    79       2
# dodge colt m/m                       2075          15.9    77       1
# chevrolet malibu                     3155          18.2    78       1
# toyota corona                        1649          16.5    74       3
# plymouth fury iii                    4312           8.5    70       1
# amc hornet                           2774          15.5    70       1
# chevrolet caprice classic            3880          12.5    77       1
# oldsmobile cutlass salon brougham    3365          15.5    78       1
# oldsmobile vista cruiser             4499          12.5    73       1
#
#                                    cluster_km  cluster_km2
# name
# maxda glc deluxe                            2            0
# mercedes benz 300d                          0            0
# dodge colt m/m                              2            0
# chevrolet malibu                            0            0
# toyota corona                               2            0
# plymouth fury iii                           1            1
# amc hornet                                  1            2
# chevrolet caprice classic                   1            2
# oldsmobile cutlass salon brougham           1            2
# oldsmobile vista cruiser                    1            2

# %%
# Here is a plot of the new clusters produced with a different randomization. Totally different!

fig, ax = plt.subplots(1, 1, figsize=(8,8))
ax.scatter(sample10['mpg'], sample10['weight'], c=sample10['cluster_km2'])
ax.set_title("K-Means Clustering Results with K=3")
ax.set_xlabel('mpg')
ax.set_ylabel('weight');

# %%
# We can automatically have the algorithm repeat itself many times and then take the optimal answer...
# here we use 100 iterations.

kmeans3 = KMeans(n_clusters=3,
                random_state=1,
                n_init=100).fit(sample10_scale)
cluster_km3 = pd.DataFrame(kmeans3.labels_)
cluster_km3.index=sample10.index
cluster_km3
# Out:
#                                    0
# name
# maxda glc deluxe                   1
# amc hornet                         2
# chevrolet caprice classic          0
# oldsmobile cutlass salon brougham  2
# mercedes benz 300d                 2
# plymouth fury iii                  0
# oldsmobile vista cruiser           0
# dodge colt m/m                     1
# chevrolet malibu                   2
# toyota corona                      1

# %%
sample10['cluster_km3']=cluster_km3
sample10.sort_values('cluster_km3')
# Out:
# /var/folders/7v/vty5zngd6bz1whcwtx15zmp00000gn/T/ipykernel_23846/4152311095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample10['cluster_km3']=cluster_km3
#                                     mpg  cylinders  displacement  horsepower  \
# name
# chevrolet caprice classic          17.5          8         305.0         145
# plymouth fury iii                  14.0          8         440.0         215
# oldsmobile vista cruiser           12.0          8         350.0         180
# maxda glc deluxe                   34.1          4          86.0          65
# dodge colt m/m                     33.5          4          98.0          83
# toyota corona                      31.0          4          76.0          52
# amc hornet                         18.0          6         199.0          97
# oldsmobile cutlass salon brougham  19.9          8         260.0         110
# mercedes benz 300d                 25.4          5         183.0          77
# chevrolet malibu                   20.5          6         200.0          95
#
#                                    weight  acceleration  year  origin  \
# name
# chevrolet caprice classic            3880          12.5    77       1
# plymouth fury iii                    4312           8.5    70       1
# oldsmobile vista cruiser             4499          12.5    73       1
# maxda glc deluxe                     1975          15.2    79       3
# dodge colt m/m                       2075          15.9    77       1
# toyota corona                        1649          16.5    74       3
# amc hornet                           2774          15.5    70       1
# oldsmobile cutlass salon brougham    3365          15.5    78       1
# mercedes benz 300d                   3530          20.1    79       2
# chevrolet malibu                     3155          18.2    78       1
#
#                                    cluster_km  cluster_km2  cluster_km3
# name
# chevrolet caprice classic                   1            2            0
# plymouth fury iii                           1            1            0
# oldsmobile vista cruiser                    1            2            0
# maxda glc deluxe                            2            0            1
# dodge colt m/m                              2            0            1
# toyota corona                               2            0            1
# amc hornet                                  1            2            2
# oldsmobile cutlass salon brougham           1            2            2
# mercedes benz 300d                          0            0            2
# chevrolet malibu                            0            0            2

# %%
# Here is the plot for the 'optimal'

fig, ax = plt.subplots(1, 1, figsize=(8,8))
ax.scatter(sample10['mpg'], sample10['weight'], c=sample10['cluster_km3'])
ax.set_title("K-Means Clustering Results with K=3")
ax.set_xlabel('mpg')
ax.set_ylabel('weight');

# %%
# we can plot by different variables, too
# can you find a pair of variables that show a meaningful difference between the clusters?

fig, ax = plt.subplots(1, 1, figsize=(8,8))
ax.scatter(sample10['year'], sample10['origin'], c=sample10['cluster_km3'])
ax.set_title("K-Means Clustering Results with K=3");
ax.set_xlabel('year')
ax.set_ylabel('origin');

# %%
# We can create a function to run k-means and make these plots automatically

def kmeans_plot(data=sample10,n_clusters=3,var1='mpg',var2='weight'):
    data_scale = scaler.fit_transform(data)
    kmeans = KMeans(n_clusters=n_clusters,
                    random_state=1,
                    n_init=100).fit(data_scale)
    cluster_km = pd.DataFrame(kmeans.labels_)
    cluster_km.index=data.index
    fig, ax = plt.subplots(1, 1, figsize=(8,8))
    ax.scatter(data[var1], data[var2], c=cluster_km)
    ax.set_title("K-Means Clustering Results with K={}".format(n_clusters))
    ax.set_xlabel(var1)
    ax.set_ylabel(var2);

# %%
# can you find a pair of variables that are important when you have 5 different clusters?

kmeans_plot(data=Auto,
            n_clusters=4,
            var1='horsepower',
            var2='acceleration')

# %%
kmeans_plot(data=Auto,
            n_clusters=5,
            var1='mpg',
            var2='displacement')
